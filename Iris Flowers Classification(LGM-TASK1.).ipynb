# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import svm, datasets

# %%
pwd
# Out:
# 'C:\\Users\\91703\\ProjectLGM'

# %%
df = pd.read_csv('C:\\Users\\91703\\ProjectLGM\\IRIS.csv')

# %%
df.head()
# Out:
#    SepalLenghtCm  SetalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#      SepalLenghtCm  SetalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLenghtCm  150 non-null    float64
#  1   SetalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.nunique()
# Out:
# SepalLenghtCm    35
# SetalWidthCm     23
# PetalLengthCm    43
# PetalWidthCm     22
# Species           3
# dtype: int64

# %%
df.describe()
# Out:
#        SepalLenghtCm  SetalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df.keys
# Out:
# <bound method NDFrame.keys of      SepalLenghtCm  SetalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# ...

# %%
df.values
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'Iris-setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'Iris-setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'Iris-setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'Iris-setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'Iris-setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'Iris-setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'Iris-setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'Iris-setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'Iris-setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'Iris-setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'Iris-setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'Iris-setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'Iris-setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'Iris-setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'Iris-setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'Iris-setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'Iris-setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'Iris-setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'Iris-setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'Iris-setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'Iris-setosa'],
# ...

# %%
df.shape
# Out:
# (150, 5)

# %%
df.isna()
# Out:
#      SepalLenghtCm  SetalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            False         False          False         False    False
# 1            False         False          False         False    False
# 2            False         False          False         False    False
# 3            False         False          False         False    False
# 4            False         False          False         False    False
# ..             ...           ...            ...           ...      ...
# 145          False         False          False         False    False
# 146          False         False          False         False    False
# 147          False         False          False         False    False
# 148          False         False          False         False    False
# 149          False         False          False         False    False
#
# [150 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# SepalLenghtCm    0
# SetalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
df.columns
# Out:
# Index(['SepalLenghtCm', 'SetalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# # Scatter Plot

# %%
for i in df.columns:
    plt.scatter(df[str(i)],df['SepalLenghtCm'])
    plt.xlabel(i)
    plt.ylabel("Sepal Length Cm")
    plt.show()

# %%
sns.pairplot(df, hue = 'Species')

# %%
df.corr()
# Out:
# C:\Users\91703\AppData\Local\Temp\ipykernel_18764\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                SepalLenghtCm  SetalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLenghtCm       1.000000     -0.109369       0.871754      0.817954
# SetalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
df.columns
# Out:
# Index(['SepalLenghtCm', 'SetalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# coL = ['SepalLengthCm','SepalWidthCm','PetalLength',PetalWidthCm]
# plt.figsize= (35,5)
# i = 1
# for j in col:
#     plt.subplot(1,10,i)
#     sns.distplot(df[j])
#     i = i+1
#     plt.tight_layout()
#     plt.show()

# %%
# plt.figure(figsize=(10,10))
#sns.headmap(df.corr(),cmap = 'Blue',annot = True)

# %%
df.describe()
# Out:
#        SepalLenghtCm  SetalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # FacetGrit

# %%
sns.FacetGrid(df, hue = "Species", height = 5).map(sns.distplot,"SepalLenghtCm").add_legend()
# Out:
# C:\Users\91703\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\91703\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.FacetGrid(df, hue = "Species", height = 5).map(sns.distplot,"SetalWidthCm").add_legend()
# Out:
# C:\Users\91703\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\91703\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.FacetGrid(df, hue = "Species", height = 5).map(sns.distplot,"PetalLengthCm").add_legend()
# Out:
# C:\Users\91703\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\91703\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.FacetGrid(df, hue = "Species", height = 5).map(sns.distplot,"PetalWidthCm").add_legend()
# Out:
# C:\Users\91703\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\91703\anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# # SubPlots

# %%
fig, axes = plt.subplots(2,2, figsize=(16,12))
axes[0,0].set_title("Distrubution of Sepal Lenght")
sns.boxplot(y = "SepalLenghtCm", x ="Species", data= df , orient = 'v',ax = axes[0,0])
axes[0,1].set_title("Distribution of Setal Width")
sns.boxplot(y = "SetalWidthCm", x ="Species", data= df , orient = 'v',ax = axes[0,1])
axes[1,0].set_title("Distribution of Petal Length ")
sns.boxplot(y = "PetalLengthCm", x ="Species", data= df , orient = 'v',ax = axes[1,0])
axes[1,1].set_title("Distribution of Petal Width ")
sns.boxplot(y = "PetalWidthCm", x ="Species", data= df , orient = 'v',ax = axes[1,1])
plt.show()

# %% [markdown]
# # ViolinPLot

# %%
fig, axes = plt.subplots(2,2, figsize=(16,12))
axes[0,0].set_title("Distribition of Sepal Lenght")
sns.violinplot(y = "SepalLenghtCm", x ="Species",data= df ,orient = 'v', ax = axes[0,0])
axes[0,1].set_title("Distribition of Setal width")
sns.violinplot(y = "SetalWidthCm", x ="Species",data= df ,orient = 'v', ax = axes[0,1])
axes[1,0].set_title("Distribition of Petal Length")
sns.violinplot(y = "PetalLengthCm", x ="Species",data= df ,orient = 'v', ax = axes[1,0])
axes[1,1].set_title("Distribition of Petal Width")
sns.violinplot(y = "PetalWidthCm", x ="Species",data= df ,orient = 'v', ax = axes[1,1])
plt.show()

# %% [markdown]
# # Histogram Plot

# %%
fig, axes = plt.subplots(2,2, figsize=(16,12))
axes[0,0].set_title("Distribution of Sepal Lenght")
axes[0,0].hist(df["SepalLenghtCm"],bins = 5);
axes[0,1].set_title("Distribution of Setal Width")
axes[0,1].hist(df["SetalWidthCm"],bins = 8);
axes[1,0].set_title("Distribution of Petal Length")
axes[1,0].hist(df["PetalLengthCm"],bins = 5);
axes[1,1].set_title("Distribution of Petal Width")
axes[1,1].hist(df["PetalWidthCm"],bins = 8);
plt.show()

# %%
df.corr()
# Out:
# C:\Users\91703\AppData\Local\Temp\ipykernel_18764\336072226.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                SepalLenghtCm  SetalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLenghtCm       1.000000     -0.109369       0.871754      0.817954
# SetalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
sns.stripplot( y = 'SepalLenghtCm', x = 'Species', data = df)
plt.show()

# %%
#seperat features and target
data = df.values
X = data[:,0:4]
Y = data[:,4]

# %% [markdown]
# # Train And Test Data

# %%
#split the data to train and test
from sklearn.model_selection import train_test_split
x_train, x_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2)

# %% [markdown]
# # Sopport Vector Machine

# %%
#support vector machine algorithm
from sklearn.svm import SVC
svn = SVC()
svn.fit(x_train, Y_train)
# Out:
# SVC()

# %%
#predict form the dataset
predictions = svn.predict(x_test)

# %% [markdown]
# # Test Model

# %%
#Test the model 
x_new = np.array([[2,3,5,5],[1,2,3.8,0],[5.3,2.5,4.6,1.9]])
#prediction of the species from the input vector
prediction = svn.predict(x_new)
print("Prediction of Species: {}".format(prediction))
# Out:
# Prediction of Species: ['Iris-virginica' 'Iris-versicolor' 'Iris-virginica']

# %% [markdown]
# # Thank You!
